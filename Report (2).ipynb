# %% [markdown]
# Note:
# If you can't see the images, please go to this link.
# https://drive.google.com/file/d/1cTleugAa3yTQwzYh35XKM824Xg6qtqs7/view?usp=sharing

# %% [markdown]
# # Introduction

# %% [markdown]
# People who live in the city can find innumerable types of stores to consume what they want. At the same time, too many stores located in the same neighborhood produce high competition between businesses. That said, a customer with multiple stores of the same type around him will be assumed to be a risky customer.
# Any company wants to keep their clients to ensure future sales, but this comes at a cost, whether in advertising, promotions, discounts or other. The main problem here it is, how can I identify which customers of my client portfolio are more likely to leave with another shop that offer similar products.
# In summary, the business problem it is identifies which customers have more similar shops around their addresses and then classify them as a client with a lot of offer or with the poor offer around him.
# This tool it is going to be interested for any enterprise or individual business to classify their client portfolio and take decisions about what to do in the future.

# %% [markdown]
# # Data

# %% [markdown]
# To solve this problem, we only need a dataset with all the home address of our client portfolio.
# Once we have this, Foursquare API is going to help us to find each latitude and longitude of the address of each customer and then it is necessary obtained the number of places belonging to the same category that are nearby to that specific customer.
# In this case, I am going to do this exercise with my uncle's business. A few months ago, he started a business that provides coffee and food as a delivery. For the moment I have the address list of his customers and it is going to be the data to use in this Capstone Project.
# In summary, using the address of each customer, Foursquare is going to find the latitude and longitude. After this, Foursquare is going to help us provide the frequency of coffee shops that are nearby to that specific customer.
# This process must repeat with every customer to then normalize the data and finally classify each one in a cluster.

# %% [markdown]
# # Methodology

# %% [markdown]
# 1) Import addresses

# %% [markdown]
# ![image.png](attachment:93991875-df2b-4a2e-ab06-4853a3f9ae4c.png)

# %% [markdown]
# 2) Get from Foursquare latitude and longitude using the addresses

# %% [markdown]
# ![image.png](attachment:80233b71-be45-4a78-ae25-0d7d19d6024d.png)

# %% [markdown]
# 3) Show each customer in a Map

# %% [markdown]
# ![image.png](attachment:9272e102-0eb4-4e3b-8585-ad5140e03d9d.png)

# %% [markdown]
# 4) Ask to Foursquare how many coffee shops are nearby of each customer within a radius of 500 meters

# %% [markdown]
# ![image.png](attachment:99162bb3-e0a7-4266-b563-fd19524be392.png)

# %% [markdown]
# 5) Count frequency of Coffee Shops nearby each customer

# %% [markdown]
# ![image.png](attachment:f5c83846-99c5-4b97-a4e6-5155126b00c3.png)

# %% [markdown]
# 6) Clustering

# %% [markdown]
# ![image.png](attachment:8c3bd6be-5814-4742-b6b6-227a09125049.png)

# %% [markdown]
# 7) Show Map for clustering customers:

# %% [markdown]
# ![image.png](attachment:0abbe47e-1c22-47a9-bea4-e21090d6de88.png)

# %% [markdown]
# # Results

# %% [markdown]
# ![image.png](attachment:2ee0733b-a4a0-4828-92a4-401031b0e819.png)

# %% [markdown]
# # Discusion

# %% [markdown]
# If we sort the results by frequency of Coffee Shop per each customer, we obtain:
#
# ![image.png](attachment:7e75528b-36bc-4b78-b4cd-12512a5b9919.png)

# %% [markdown]
# As we can see, customers were clustered in 3 different groups.
#
# Cluster Label = 0 /
# These customers have in common that they do not have too many coffee shops around their homes.
#
# Cluster Label = 1 /
# These ones have too much coffee shops nearby. Their frequencies go from 18 to 26 coffees shops within a radius of 500 meters!
#
# Cluster Label = 2 /
# Have less places to go for a cup of coffee than cluster label 1 and more options than cluster label 0.

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1) Cluster 1 customers have many options where to buy when they want to consume a cup of coffee. These ones correspond to a client with a high risk of leaving with the competition.

# %% [markdown]
# 2) Customers that belong to Cluster 0 do not have to many choices when they want to get a cup of coffee. So if our coffee shop provides a good service that will be enough to keep the customer whit us.

# %% [markdown]
# 3) Customers that belong to Cluster 2 have a medium risk of leaving with the competition. They have a few alternatives to choose around their house.

# %% [markdown]
# #### Recomendation

# %% [markdown]
# This project consisted in detecting which customers have more offer nearby their home addresses considering one shop category (coffee). My recommendation as a Data Scientist to the manager is paying more attention to customers that belong to Cluster1. If your Coffee Shop does not provide a good service or prices are too expensive to these, they are going to change your coffee shop for another one in a fast way.
